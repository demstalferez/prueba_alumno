# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv("coches.csv",index_col = 'company')

# %%
df
# Out:
#                                            make      model  \
# company
# 9881BCDD5A0AD4733037B3FB25E69C3A            KIA   Carnival
# 9881BCDD5A0AD4733037B3FB25E69C3A            BMW    Serie 5
# 9881BCDD5A0AD4733037B3FB25E69C3A           FIAT        500
# 9881BCDD5A0AD4733037B3FB25E69C3A           OPEL      Astra
# 9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ    Clase C
# ...                                         ...        ...
# 9881BCDD5A0AD4733037B3FB25E69C3A           OPEL      Corsa
# 9881BCDD5A0AD4733037B3FB25E69C3A         TOYOTA      Auris
# 9881BCDD5A0AD4733037B3FB25E69C3A        PEUGEOT    Partner
# 9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ  GLC Coupé
# 9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ   Clase SL
#
#                                                                           version  \
# company
# 9881BCDD5A0AD4733037B3FB25E69C3A                 KIA Carnival 2.9 CRDi VGT EX 5p.
# ...

# %%
df.dtypes
# Out:
# make                object
# model               object
# version             object
# price                int64
# price_financed     float64
# fuel                object
# year                 int64
# kms                  int64
# power              float64
# doors              float64
# shift               object
# color               object
# photos               int64
# is_professional       bool
# dealer              object
# phone               object
# province            object
# publish_date        object
# insert_date         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# make                  0
# model                 4
# version               0
# price                 0
# price_financed     2732
# fuel                  8
# year                  0
# kms                   0
# power               946
# doors                 4
# shift                10
# color                58
# photos                0
# is_professional       0
# dealer                0
# phone                 0
# province              0
# publish_date          0
# insert_date           0
# dtype: int64

# %%
df.drop(['price_financed','color','photos','phone','power','doors'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (5000, 13)

# %%
df.isnull().sum()
# Out:
# make                0
# model               4
# version             0
# price               0
# fuel                8
# year                0
# kms                 0
# shift              10
# is_professional     0
# dealer              0
# province            0
# publish_date        0
# insert_date         0
# dtype: int64

# %%
moda_fuel=df['fuel'].mode

# %%
moda_shift=df['shift'].mode

# %%
df['fuel'].fillna(0, inplace=True)
df['shift'].fillna(0, inplace=True)

# %%
df['fuel'].replace(0, moda_fuel)
# Out:
# company
# 9881BCDD5A0AD4733037B3FB25E69C3A      Diésel
# 9881BCDD5A0AD4733037B3FB25E69C3A      Diésel
# 9881BCDD5A0AD4733037B3FB25E69C3A    Gasolina
# 9881BCDD5A0AD4733037B3FB25E69C3A      Diésel
# 9881BCDD5A0AD4733037B3FB25E69C3A      Diésel
#                                       ...
# 9881BCDD5A0AD4733037B3FB25E69C3A    Gasolina
# 9881BCDD5A0AD4733037B3FB25E69C3A    Gasolina
# 9881BCDD5A0AD4733037B3FB25E69C3A      Diésel
# 9881BCDD5A0AD4733037B3FB25E69C3A      Diésel
# 9881BCDD5A0AD4733037B3FB25E69C3A    Gasolina
# Name: fuel, Length: 5000, dtype: object

# %%
df['shift'].replace(0, moda_shift)
# Out:
# company
# 9881BCDD5A0AD4733037B3FB25E69C3A        Manual
# 9881BCDD5A0AD4733037B3FB25E69C3A        Manual
# 9881BCDD5A0AD4733037B3FB25E69C3A        Manual
# 9881BCDD5A0AD4733037B3FB25E69C3A        Manual
# 9881BCDD5A0AD4733037B3FB25E69C3A    Automático
#                                        ...
# 9881BCDD5A0AD4733037B3FB25E69C3A        Manual
# 9881BCDD5A0AD4733037B3FB25E69C3A        Manual
# 9881BCDD5A0AD4733037B3FB25E69C3A        Manual
# 9881BCDD5A0AD4733037B3FB25E69C3A    Automático
# 9881BCDD5A0AD4733037B3FB25E69C3A    Automático
# Name: shift, Length: 5000, dtype: object

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot: ylabel='company'>

# %%
df.corr(method = 'pearson').sort_values(by = 'is_professional', axis = 0).sort_values(by = 'is_professional', axis = 1)
# Out:
#                       kms     price      year  is_professional
# kms              1.000000 -0.456111 -0.682102        -0.500631
# price           -0.456111  1.000000  0.504757         0.386594
# year            -0.682102  0.504757  1.000000         0.631232
# is_professional -0.500631  0.386594  0.631232         1.000000

# %%
corr = df.corr(method = 'pearson').sort_values(by = 'is_professional', axis = 0, ascending = False).sort_values(by = 'is_professional', axis = 1, ascending = False)
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
 
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8,8))
 
# Generate a custom diverging colormap  
cmap = sns.diverging_palette(150, 275, l=55, as_cmap=True)
 
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr.iloc[0:,0:], mask=mask[0:,0:], cmap=cmap, vmax=1, center=0,
            square=True, linewidths=3, cbar_kws={"shrink": .8}, annot = True)
# Out:
# <AxesSubplot: >

# %%
df['make'].unique()
# Out:
# array(['KIA', 'BMW', 'FIAT', 'OPEL', 'MERCEDES-BENZ', 'PEUGEOT',
#        'VOLKSWAGEN', 'FORD', 'RENAULT', 'CITROEN', 'SEAT', 'VOLVO',
#        'NISSAN', 'LAND-ROVER', 'MINI', 'AUDI', 'HONDA', 'DS', 'SKODA',
#        'MITSUBISHI', 'LEXUS', 'BENTLEY', 'ROVER', 'PORSCHE', 'FERRARI',
#        'HYUNDAI', 'TOYOTA', 'DACIA', 'MAZDA', 'ALFA ROMEO', 'INFINITI',
#        'JAGUAR', 'LANCIA', 'CHEVROLET', 'ABARTH', 'SSANGYONG', 'JEEP',
#        'SMART', 'SUZUKI', 'SAAB', 'DFSK', 'SUBARU', 'MASERATI', 'IVECO',
#        'ASTON MARTIN', 'DODGE', 'CHRYSLER', 'ROLLS-ROYCE', 'HUMMER',
#        'TESLA', 'DAEWOO', 'ISUZU', 'MG', 'LADA', 'TATA', 'GALLOPER'],
#       dtype=object)

# %%
px.histogram(df, x='make', title='cantidad de coches por marca', labels={'make':'Marcas'},color= 'make').update_xaxes(categoryorder='total descending')

# %%
color = ["Red", "Blue", "white"] 
sns.set_palette(color) 
c = sns.countplot(x='shift', data=df)
c.set(title = 'tipo de caja de cambio')
# Out:
# [Text(0.5, 1.0, 'tipo de caja de cambio')]

# %%
sns.set(rc = {'figure.figsize':(10,5)})
f = sns.countplot(x='fuel', data=df)
f.set(title = 'tipos de combustible')
# Out:
# [Text(0.5, 1.0, 'tipos de combustible')]

# %%
df['year'].unique()
# Out:
# array([2007, 2001, 2017, 2009, 2008, 2002, 2020, 2010, 2015, 2000, 2012,
#        2014, 2016, 2019, 2018, 2005, 2006, 2013, 2003, 1999, 2004, 1998,
#        2011, 2021, 1988, 1997, 1994, 1986, 1991, 1995, 1992, 1982, 1990,
#        1987, 1996, 1979, 1983, 1993, 1984, 1971, 1989, 1972])

# %%
px.histogram(df, x='year', title='coches por año de fabrcacion en venta', labels={'year':'Años'},color= 'year')

# %%
px.histogram(df, x='fuel', title='marca de coches en venta segun su combustible', labels={'make':'Marcas'},color= 'make')

# %%
px.histogram(df, x='province', title='cantidad de coches por provincia', labels={'province':'Provincias'}).update_xaxes(categoryorder='total descending')

# %%
px.violin(df, y="price")

# %%
px.scatter(df,x='make', y='price', title='precio segun marcas',color='make')

# %%
px.scatter(df, x='price', y='year', color='price',title='precio segun el año de fabrcacion')

# %%
px.scatter(df, x='price', y='fuel', color='price',title='precio segun combustible')

# %%
px.scatter(df, x='price', y='kms', color='price',title='precio segun kilometros')

# %%
px.pie(df, values='price', names='shift', title='precio segun caja de cambios')

# %%
# quiero usar tres variables para identificar la mejor opcion de compra año km y precio del coche
#  y con ello sacar un top5

# %%
df[['make', 'model','year','kms','price']].value_counts().head(5)
# Out:
# make           model      year  kms     price
# PEUGEOT        407 SW     2004  400000  1000     3
# MERCEDES-BENZ  Clase CLK  2007  56700   10500    2
# NISSAN         NOTE       2012  100000  4900     2
# VOLVO          XC60       2009  189950  10900    2
# FORD           Mondeo     2005  189000  2000     2
# dtype: int64

# %%
#Guardar en un nuevo csv 
df.to_csv('nuevo.csv', index=False)

# %%
from pycaret. regression import *

# %%
import pandas as pd
df_coches = pd.read_csv("nuevo.csv")

# %%
df_coches.columns
# Out:
# Index(['make', 'model', 'version', 'price', 'fuel', 'year', 'kms', 'shift',
#        'is_professional', 'dealer', 'province', 'publish_date', 'insert_date'],
#       dtype='object')

# %%
#Label encoder para cada columna

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

def l_encoder(df):
    for i in df.columns:
        df[i] = le.fit_transform(df[i].values)
    return df 

l_encoder(df_coches)
# Out:
#       make  model  version  price  fuel  year   kms  shift  is_professional  \
# 0       26    141     1259    157     1    27  1865      2                1
# 1        5    474      408     50     1    21  1834      2                0
# 2       15     36      769    208     5    37  1100      2                1
# 3       38     83     1897    178     1    29  1583      2                0
# 4       33    152     1523    388     1    28  1294      1                1
# ...    ...    ...      ...    ...   ...   ...   ...    ...              ...
# 4995    38    191     1975    329     5    38   401      2                1
# 4996    53     86     2936    249     5    36  1677      2                0
# 4997    39    391     2319    199     1    32  1509      2                0
# 4998    33    257     1683   1052     1    39    14      1                1
# 4999    33    170     1664    423     5    23  1539      1                1
#
#       dealer  province  publish_date  insert_date
# ...

# %%
df_coches.to_csv('nuevo.csv', index=False)

# %%
modelito = setup(data=df_coches, target='price')
# Out:
# <style type="text/css">
# #T_fe3e8_row7_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fe3e8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe3e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe3e8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fe3e8_row0_col1" class="data row0 col1" >2908</td>
#     </tr>
#     <tr>
#       <th id="T_fe3e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fe3e8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fe3e8_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_fe3e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fe3e8_row2_col0" class="data row2 col0" >Target type</td>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_6fbc3_ th {
#   text-align: left;
# }
# ...

# %%
lightgbm = create_model('lightgbm') 
plot_model(lightgbm, plot='feature')
# Out:
# <style type="text/css">
# #T_4280b_row10_col0, #T_4280b_row10_col1, #T_4280b_row10_col2, #T_4280b_row10_col3, #T_4280b_row10_col4, #T_4280b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4280b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
tune_model(lightgbm)
# Out:
# <style type="text/css">
# #T_2756a_row10_col0, #T_2756a_row10_col1, #T_2756a_row10_col2, #T_2756a_row10_col3, #T_2756a_row10_col4, #T_2756a_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2756a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
plot_model(lightgbm)

# %%
save_model(lightgbm, model_name="Coches_gbr")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=/tmp/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['make', 'model', 'version', 'fuel',
#                                               'year', 'kms', 'shift',
#                                               'is_professional', 'dealer',
#                                               'province', 'publish_date',
#                                               'insert_date'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                missing_values=nan,
#                                                                strategy='mean',
# ...
